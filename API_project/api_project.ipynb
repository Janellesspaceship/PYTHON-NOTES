# %%
import requests

API_KEY = "af17064781c866135aaaab063ffc38eb"
city = "Forks"

url = f"https://openweathermap.org/city/5794761={Forks}&appid={af17064781c866135aaaab063ffc38eb}&units=metric"

response = requests.get(https://openweathermap.org/city/5794761)
data = response.json()

print("Temperature:", data["main"]["temp"], "\u00b0C")
# Out:
#   Cell In[1], line 8
#     response = requests.get(https://openweathermap.org/city/5794761)
#                                  ^
# SyntaxError: invalid syntax
