# %%
! pip install requests
# Out:
# Requirement already satisfied: requests in .\jay\Lib\site-packages (2.33.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\jay\Lib\site-packages (from requests) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in .\jay\Lib\site-packages (from requests) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in .\jay\Lib\site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in .\jay\Lib\site-packages (from requests) (2026.4.22)

# %%
import requests

api_key = "af17064781c866135aaaab063ffc38eb"   
city = "Forks"

url = f"https://api.openweathermap.org/data/2.5/weather?q={city}&appid={api_key}&units=metric"

response = requests.get(url)

# Check if request was successful
if response.status_code == 200:
    data = response.json()

    temperature = data["main"]["temp"]
    weather = data["weather"][0]["description"]

    print(f"City: {city}")
    print(f"Temperature: {temperature}°C")
    print(f"Weather: {weather}")

else:
    print("Error:", response.status_code)
    print(response.text)
# Out:
# City: Forks
# Temperature: 8.84°C
# Weather: clear sky

# %%
import requests

api_token = "e7VZYesjT1yuph9MCWk19Z2x7jRvp4QvRRxL"

base_url = "https://www.iucnredlist.org/api/v4"

def get_endangered_species()
